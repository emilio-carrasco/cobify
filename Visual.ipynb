# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/mediciones.csv')

# %% [markdown]
# # Exploracion

# %%
df
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0         28       5     26        21,5            12      NaN      E10   0
# 1         12     4,2     30        21,5            13      NaN      E10   0
# 2       11,2     5,5     38        21,5            15      NaN      E10   0
# 3       12,9     3,9     36        21,5            14      NaN      E10   0
# 4       18,5     4,5     46        21,5            15      NaN      E10   0
# ..       ...     ...    ...         ...           ...      ...      ...  ..
# 383       16     3,7     39        24,5            18      NaN     SP98   0
# 384     16,1     4,3     38          25            31       AC     SP98   1
# 385       16     3,8     45          25            19      NaN     SP98   0
# 386     15,4     4,6     42          25            31       AC     SP98   1
# 387     14,7       5     25          25            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# 0       0    0            45        E10
# 1       0    0           NaN        NaN
# 2       0    0           NaN        NaN
# 3       0    0           NaN        NaN
# 4       0    0           NaN        NaN
# ..    ...  ...           ...        ...
# 383     0    0           NaN        NaN
# 384     0    0           NaN        NaN
# 385     0    0           NaN        NaN
# 386     0    0           NaN        NaN
# 387     0    0           NaN        NaN
#
# [388 rows x 12 columns]

# %% [markdown]
# Vemos que hay diferente tipado en el dataset:

# %%
df.dtypes
# Out:
# distance         object
# consume          object
# speed             int64
# temp_inside      object
# temp_outside      int64
# specials         object
# gas_type         object
# AC                int64
# rain              int64
# sun               int64
# refill liters    object
# refill gas       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       388 non-null    object
#  1   consume        388 non-null    object
#  2   speed          388 non-null    int64
#  3   temp_inside    376 non-null    object
#  4   temp_outside   388 non-null    int64
#  5   specials       93 non-null     object
#  6   gas_type       388 non-null    object
#  7   AC             388 non-null    int64
#  8   rain           388 non-null    int64
#  9   sun            388 non-null    int64
#  10  refill liters  13 non-null     object
#  11  refill gas     13 non-null     object
# dtypes: int64(5), object(7)
# memory usage: 36.5+ KB

# %% [markdown]
# # Limpieza

# %% [markdown]
# Muchos de ellos deberemos pasarlos directamente a valores numéricos:
#
#
# En primer lugar muchos números están expresados como cadenas de caracteres y con comas:

# %%
df.columns
# Out:
# Index(['distance', 'consume', 'speed', 'temp_inside', 'temp_outside',
#        'specials', 'gas_type', 'AC', 'rain', 'sun', 'refill liters',
#        'refill gas'],
#       dtype='object')

# %%
df[['distance', 'consume', 'temp_inside', 'refill liters']] = df[['distance', 'consume', 'temp_inside', 'refill liters']].apply(lambda x: x.str.replace(',','.'))

# %%
df
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0         28       5     26        21.5            12      NaN      E10   0
# 1         12     4.2     30        21.5            13      NaN      E10   0
# 2       11.2     5.5     38        21.5            15      NaN      E10   0
# 3       12.9     3.9     36        21.5            14      NaN      E10   0
# 4       18.5     4.5     46        21.5            15      NaN      E10   0
# ..       ...     ...    ...         ...           ...      ...      ...  ..
# 383       16     3.7     39        24.5            18      NaN     SP98   0
# 384     16.1     4.3     38          25            31       AC     SP98   1
# 385       16     3.8     45          25            19      NaN     SP98   0
# 386     15.4     4.6     42          25            31       AC     SP98   1
# 387     14.7       5     25          25            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# 0       0    0            45        E10
# 1       0    0           NaN        NaN
# 2       0    0           NaN        NaN
# 3       0    0           NaN        NaN
# 4       0    0           NaN        NaN
# ..    ...  ...           ...        ...
# 383     0    0           NaN        NaN
# 384     0    0           NaN        NaN
# 385     0    0           NaN        NaN
# 386     0    0           NaN        NaN
# 387     0    0           NaN        NaN
#
# [388 rows x 12 columns]

# %%
df[['distance', 'consume', 'temp_inside', 'AC', 'rain', 'sun', 'refill liters']] = df[['distance', 'consume', 'temp_inside', 'AC', 'rain', 'sun', 'refill liters']].astype(float)

# %% [markdown]
# Tenemos ya nuestras variables numéricas en tipo correcto:

# %%
df.dtypes
# Out:
# distance         float64
# consume          float64
# speed              int64
# temp_inside      float64
# temp_outside       int64
# specials          object
# gas_type          object
# AC               float64
# rain             float64
# sun              float64
# refill liters    float64
# refill gas        object
# dtype: object

# %% [markdown]
# # Vemos la columna "specials"

# %%
df.specials.value_counts()
# Out:
# rain                  32
# sun                   27
# AC rain                9
# ac                     8
# AC                     6
# snow                   3
# sun ac                 3
# ac rain                1
# AC Sun                 1
# half rain half sun     1
# AC snow                1
# AC sun                 1
# Name: specials, dtype: int64

# %%
df[~df.specials.isna()].sample(10)
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 319     216.1      5.3     90         22.0            21      sun     SP98
# 321      16.6      4.2     52         22.0            15     rain     SP98
# 155      36.6      5.2     80         21.5             7     rain      E10
# 273      93.9      4.8     88         23.0            18   AC sun      E10
# 301      19.0      5.0     35         22.0            15   sun ac     SP98
# 367      15.4      5.0     48         25.5            31       ac     SP98
# 138      12.3      6.1     61         21.5            10     rain     SP98
# 250      31.5      4.1     30         22.5            16      sun      E10
# 40       12.4      4.0     55         21.5             7  AC rain      E10
# 245      11.8      6.1     16         22.5             6     rain      E10
#
#       AC  rain  sun  refill liters refill gas
# 319  0.0   0.0  1.0            NaN        NaN
# 321  0.0   1.0  0.0            NaN        NaN
# 155  0.0   1.0  0.0            NaN        NaN
# 273  1.0   0.0  1.0            NaN        NaN
# 301  1.0   0.0  1.0            NaN        NaN
# 367  1.0   0.0  0.0            NaN        NaN
# 138  0.0   1.0  0.0            NaN        NaN
# 250  0.0   0.0  1.0            NaN        NaN
# 40   1.0   1.0  0.0            NaN        NaN
# 245  0.0   1.0  0.0            NaN        NaN

# %% [markdown]
# En la columan 'specials' no aparece 'nieve', generamos una coliumna dummy para ello

# %%
def nieve(x):
    try:
        if 'SNOW'in x.upper():
            return 1
        else: return 0
    except:
        return 0
        
df['snow']=df.specials.apply(nieve)
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
#       AC  rain  sun  refill liters refill gas  snow
# 0    0.0   0.0  0.0           45.0        E10     0
# 1    0.0   0.0  0.0            NaN        NaN     0
# 2    0.0   0.0  0.0            NaN        NaN     0
# 3    0.0   0.0  0.0            NaN        NaN     0
# 4    0.0   0.0  0.0            NaN        NaN     0
# ..   ...   ...  ...            ...        ...   ...
# 383  0.0   0.0  0.0            NaN        NaN     0
# 384  1.0   0.0  0.0            NaN        NaN     0
# 385  0.0   0.0  0.0            NaN        NaN     0
# 386  1.0   0.0  0.0            NaN        NaN     0
# 387  1.0   0.0  0.0            NaN        NaN     0
#
# [388 rows x 13 columns]

# %% [markdown]
# Aunque sólo sea para 4 días:

# %%
df.snow.value_counts()
# Out:
# 0    384
# 1      4
# Name: snow, dtype: int64

# %% [markdown]
# # Podemos "tirar" ya 'specials'
# Parece que la columna special está aparentemente bien tabulada en las columnas de dummies correspondientes, así que podemos tirarla ahora que le hemos añadido el valor "nive".

# %%
df.drop('specials', axis=1, inplace=True)

# %%
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type   AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10  0.0   0.0
# 1        12.0      4.2     30         21.5            13      E10  0.0   0.0
# 2        11.2      5.5     38         21.5            15      E10  0.0   0.0
# 3        12.9      3.9     36         21.5            14      E10  0.0   0.0
# 4        18.5      4.5     46         21.5            15      E10  0.0   0.0
# ..        ...      ...    ...          ...           ...      ...  ...   ...
# 383      16.0      3.7     39         24.5            18     SP98  0.0   0.0
# 384      16.1      4.3     38         25.0            31     SP98  1.0   0.0
# 385      16.0      3.8     45         25.0            19     SP98  0.0   0.0
# 386      15.4      4.6     42         25.0            31     SP98  1.0   0.0
# 387      14.7      5.0     25         25.0            30     SP98  1.0   0.0
#
#      sun  refill liters refill gas  snow
# 0    0.0           45.0        E10     0
# 1    0.0            NaN        NaN     0
# 2    0.0            NaN        NaN     0
# 3    0.0            NaN        NaN     0
# 4    0.0            NaN        NaN     0
# ..   ...            ...        ...   ...
# 383  0.0            NaN        NaN     0
# 384  0.0            NaN        NaN     0
# 385  0.0            NaN        NaN     0
# 386  0.0            NaN        NaN     0
# 387  0.0            NaN        NaN     0
#
# [388 rows x 12 columns]

# %% [markdown]
# Veamos cuántos datos del repostaje tenemos:

# %%
df[~df['refill gas'].isna()]
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type   AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10  0.0   0.0
# 44        5.4      3.3     32         21.5             7     SP98  0.0   0.0
# 82       10.5      3.6     42         20.0            10     SP98  0.0   0.0
# 106     162.7      5.5     75         23.0             1     SP98  0.0   0.0
# 139      16.1      5.4     24         21.5             7      E10  0.0   1.0
# 171      44.4      4.8     38         21.5             8      E10  0.0   0.0
# 191      43.7      4.7     44         22.0             9     SP98  0.0   1.0
# 192      12.1      4.2     43         22.0             4     SP98  0.0   0.0
# 234      19.0      4.5     29         22.5            10      E10  0.0   0.0
# 274      25.7      4.9     50         22.0            10     SP98  0.0   1.0
# 313      11.3      4.3     38         22.0            17     SP98  0.0   0.0
# 325      16.6      3.7     49         22.0            17      E10  0.0   0.0
# 349      18.3      4.3     46         22.0            16     SP98  0.0   0.0
#
#      sun  refill liters refill gas  snow
# 0    0.0           45.0        E10     0
# 44   0.0           37.6       SP98     0
# 82   0.0           37.7       SP98     0
# 106  0.0           45.0       SP98     0
# 139  0.0           38.0        E10     0
# 171  0.0           38.3        E10     0
# 191  0.0           10.0       SP98     0
# 192  0.0           39.0       SP98     0
# 234  0.0           39.0        E10     0
# 274  0.0           41.0       SP98     0
# 313  0.0           37.0       SP98     0
# 325  0.0           37.7        E10     0
# 349  0.0           37.2       SP98     0

# %%
len(df[~df['refill gas'].isna()])
# Out:
# 13

# %%
df[~df['refill gas'].isna()][['refill gas', 'gas_type']]
# Out:
#     refill gas gas_type
# 0          E10      E10
# 44        SP98     SP98
# 82        SP98     SP98
# 106       SP98     SP98
# 139        E10      E10
# 171        E10      E10
# 191       SP98     SP98
# 192       SP98     SP98
# 234        E10      E10
# 274       SP98     SP98
# 313       SP98     SP98
# 325        E10      E10
# 349       SP98     SP98

# %% [markdown]
# Solo ha apuntado 13 repostajes con sus datos correspondientes. Estos datos podemos decir que se han tomado según las condiciones que nos indican:
#
# "Si el coche no se estaba enfriando lo suficiente como para tener otra medida independiente de la anterior, no lo anoto."
#
# Esto nos lleva a pensar que realmente el coche no para de trabajar prácitcamente entre desplazamiento y desplazamiento.

# %%
df['cooling']= ~df['refill gas'].isna()

df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type   AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10  0.0   0.0
# 1        12.0      4.2     30         21.5            13      E10  0.0   0.0
# 2        11.2      5.5     38         21.5            15      E10  0.0   0.0
# 3        12.9      3.9     36         21.5            14      E10  0.0   0.0
# 4        18.5      4.5     46         21.5            15      E10  0.0   0.0
# ..        ...      ...    ...          ...           ...      ...  ...   ...
# 383      16.0      3.7     39         24.5            18     SP98  0.0   0.0
# 384      16.1      4.3     38         25.0            31     SP98  1.0   0.0
# 385      16.0      3.8     45         25.0            19     SP98  0.0   0.0
# 386      15.4      4.6     42         25.0            31     SP98  1.0   0.0
# 387      14.7      5.0     25         25.0            30     SP98  1.0   0.0
#
#      sun  refill liters refill gas  snow  cooling
# 0    0.0           45.0        E10     0     True
# 1    0.0            NaN        NaN     0    False
# 2    0.0            NaN        NaN     0    False
# 3    0.0            NaN        NaN     0    False
# 4    0.0            NaN        NaN     0    False
# ..   ...            ...        ...   ...      ...
# 383  0.0            NaN        NaN     0    False
# 384  0.0            NaN        NaN     0    False
# 385  0.0            NaN        NaN     0    False
# 386  0.0            NaN        NaN     0    False
# 387  0.0            NaN        NaN     0    False
#
# [388 rows x 13 columns]

# %% [markdown]
# # Agrupamos las jornadas
#
# En el data set se diferencia el momento en el que el vehículo ha tenido suficientemente tiempo para enfriarse. Considaremos que entre uno y otro ha habido un cambio de jornada. En el resto entendemos que el coche continua trabajando.

# %%
#Podemos ver el inicio y fin de cada fila de la jornada.
inicio=list(df[df.cooling].index)
fin=inicio[1:]
fin.append(len(df))
inicio=[x+1 for x in inicio]
inicio[0]=0
inicio
# Out:
# [0, 45, 83, 107, 140, 172, 192, 193, 235, 275, 314, 326, 350]

# %%
fin
# Out:
# [44, 82, 106, 139, 171, 191, 192, 234, 274, 313, 325, 349, 388]

# %% [markdown]
# # Jornada
# Damos extraemos la jornada a la que pertemece cada recorrido

# %%
 df['jornada']=0
for j, (i,f) in enumerate(zip(inicio,fin)):
    df.loc[i:f,'jornada']=j+1

# %%
df.jornada
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 383    13
# 384    13
# 385    13
# 386    13
# 387    13
# Name: jornada, Length: 388, dtype: int64

# %%
max_jornadas = df.jornada.max()
df['km_recorridos']=0

for j in range(1,max_jornadas+1):
    df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# Out:
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();
# <ipython-input-25-ce11ab9b0af8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.km_recorridos[df.jornada == j] = df[df.jornada == j].distance.cumsum();

# %% [markdown]
# # Columna Km_recorridos.
# Podemos ver como ahora cada viaje tiene una columa más con los  kilómetros acumulados desde la última vez que el coche paró. Por lo tanto entendemos que todos estos trayectos pertenecen a la misma jornada.

# %%
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type   AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10  0.0   0.0
# 1        12.0      4.2     30         21.5            13      E10  0.0   0.0
# 2        11.2      5.5     38         21.5            15      E10  0.0   0.0
# 3        12.9      3.9     36         21.5            14      E10  0.0   0.0
# 4        18.5      4.5     46         21.5            15      E10  0.0   0.0
# ..        ...      ...    ...          ...           ...      ...  ...   ...
# 383      16.0      3.7     39         24.5            18     SP98  0.0   0.0
# 384      16.1      4.3     38         25.0            31     SP98  1.0   0.0
# 385      16.0      3.8     45         25.0            19     SP98  0.0   0.0
# 386      15.4      4.6     42         25.0            31     SP98  1.0   0.0
# 387      14.7      5.0     25         25.0            30     SP98  1.0   0.0
#
#      sun  refill liters refill gas  snow  cooling  jornada  km_recorridos
# 0    0.0           45.0        E10     0     True        1           28.0
# 1    0.0            NaN        NaN     0    False        1           40.0
# 2    0.0            NaN        NaN     0    False        1           51.2
# 3    0.0            NaN        NaN     0    False        1           64.1
# 4    0.0            NaN        NaN     0    False        1           82.6
# ..   ...            ...        ...   ...      ...      ...            ...
# 383  0.0            NaN        NaN     0    False       13          513.4
# 384  0.0            NaN        NaN     0    False       13          529.5
# 385  0.0            NaN        NaN     0    False       13          545.5
# 386  0.0            NaN        NaN     0    False       13          560.9
# 387  0.0            NaN        NaN     0    False       13          575.6
#
# [388 rows x 15 columns]

# %% [markdown]
# # Drop Columnas redudantes
# Ahora la columna refill_gas no apota ningún tipo de información .
# Algo parecido podemos considerar con refill_liters, no parece que sea de interés cuántos litros ha echado.
# Como tenemos 'km_recorridos' podemos desechar "joranada" y 'cooling'

# %%
df.drop('refill liters', axis=1, inplace=True)
df.drop('refill gas', axis=1, inplace=True)
df.drop('cooling', axis=1, inplace=True)
df.drop('jornada', axis=1, inplace=True)

# %%
gas_type_diccionario= {'E10':0, 'SP98':1}
df['gas_type'] = df['gas_type'].map(gas_type_diccionario) 

df
# Out:
#      distance  consume  speed  temp_inside  temp_outside  gas_type   AC  rain  \
# 0        28.0      5.0     26         21.5            12         0  0.0   0.0
# 1        12.0      4.2     30         21.5            13         0  0.0   0.0
# 2        11.2      5.5     38         21.5            15         0  0.0   0.0
# 3        12.9      3.9     36         21.5            14         0  0.0   0.0
# 4        18.5      4.5     46         21.5            15         0  0.0   0.0
# ..        ...      ...    ...          ...           ...       ...  ...   ...
# 383      16.0      3.7     39         24.5            18         1  0.0   0.0
# 384      16.1      4.3     38         25.0            31         1  1.0   0.0
# 385      16.0      3.8     45         25.0            19         1  0.0   0.0
# 386      15.4      4.6     42         25.0            31         1  1.0   0.0
# 387      14.7      5.0     25         25.0            30         1  1.0   0.0
#
#      sun  snow  km_recorridos
# 0    0.0     0           28.0
# 1    0.0     0           40.0
# 2    0.0     0           51.2
# 3    0.0     0           64.1
# 4    0.0     0           82.6
# ..   ...   ...            ...
# 383  0.0     0          513.4
# 384  0.0     0          529.5
# 385  0.0     0          545.5
# 386  0.0     0          560.9
# 387  0.0     0          575.6
#
# [388 rows x 11 columns]

# %% [markdown]
# ¿Qué hacer con la temperatura? Hechemos un vistazo al¡ la distribución de la tempratura interior.

# %%
df.temp_inside.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# y la exterior

# %%
df.temp_outside.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Suponemos qeu la temperatura interior no es determinante, además está directamete relacionada con el uso o no de AC.
#
# En cambio, aunque no somos expertos en otores, consultamos en web y encontramos:
#
# https://www.nrcan.gc.ca/sites/www.nrcan.gc.ca/files/oee/pdf/transportation/fuel-efficient-technologies/autosmart_factsheet_3_e.pdf
#
# "Cold weather causes higher fuel consumption.  The U.S. Environmental Protection Agency (EPA) estimates that a drop in temperature from 24°C to 7°C can increase fuel consumption in urban commutes by 12 to 28%"
#
# Nos quedamos con la temp Ext y desechamos la interior por entender que no influye en el consumo.

# %%
df.drop('temp_inside', axis=1, inplace=True)

# %%
df.speed.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.astype(float).corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
df.corr()
# Out:
#                distance   consume     speed  temp_outside  gas_type        AC  \
# distance       1.000000 -0.128967  0.562299      0.088175 -0.053411 -0.025738
# consume       -0.128967  1.000000 -0.227866     -0.320811 -0.015327  0.096591
# speed          0.562299 -0.227866  1.000000      0.015411 -0.097360 -0.035408
# temp_outside   0.088175 -0.320811  0.015411      1.000000  0.148705  0.167562
# gas_type      -0.053411 -0.015327 -0.097360      0.148705  1.000000  0.105285
# AC            -0.025738  0.096591 -0.035408      0.167562  0.105285  1.000000
# rain          -0.019791  0.248118  0.009489     -0.186315  0.060328  0.242915
# sun            0.081120 -0.170667  0.081618      0.346903  0.022761  0.088598
# snow          -0.033712  0.072961  0.032481     -0.162367  0.033665  0.065984
# km_recorridos  0.120351 -0.133719  0.062908      0.065366 -0.011499  0.108353
#
#                    rain       sun      snow  km_recorridos
# distance      -0.019791  0.081120 -0.033712       0.120351
# consume        0.248118 -0.170667  0.072961      -0.133719
# speed          0.009489  0.081618  0.032481       0.062908
# temp_outside  -0.186315  0.346903 -0.162367       0.065366
# gas_type       0.060328  0.022761  0.033665      -0.011499
# AC             0.242915  0.088598  0.065984       0.108353
# rain           1.000000 -0.112650  0.271633      -0.043437
# sun           -0.112650  1.000000 -0.030600       0.067450
# snow           0.271633 -0.030600  1.000000      -0.043244
# km_recorridos -0.043437  0.067450 -0.043244       1.000000

# %% [markdown]
# # Algunas columnas que podrían ser interesantes para mostrar gráfica

# %%
precio_litro_dicc= {'E10':1.38, 'SP98':1.46}
df['price_fuel'] = df['gas_type'].map(precio_litro_dicc )
df['euros_km'] = df.apply(lambda row: row['consume']*row['price_fuel'], axis=1)
df['cost_trip'] = df.apply(lambda row: row['euros_km']*row['distance'], axis=1)

# %%
df
# Out:
#      distance  consume  speed  temp_outside  gas_type   AC  rain  sun  snow  \
# 0        28.0      5.0     26            12         0  0.0   0.0  0.0     0
# 1        12.0      4.2     30            13         0  0.0   0.0  0.0     0
# 2        11.2      5.5     38            15         0  0.0   0.0  0.0     0
# 3        12.9      3.9     36            14         0  0.0   0.0  0.0     0
# 4        18.5      4.5     46            15         0  0.0   0.0  0.0     0
# ..        ...      ...    ...           ...       ...  ...   ...  ...   ...
# 383      16.0      3.7     39            18         1  0.0   0.0  0.0     0
# 384      16.1      4.3     38            31         1  1.0   0.0  0.0     0
# 385      16.0      3.8     45            19         1  0.0   0.0  0.0     0
# 386      15.4      4.6     42            31         1  1.0   0.0  0.0     0
# 387      14.7      5.0     25            30         1  1.0   0.0  0.0     0
#
#      km_recorridos  price_fuel  euros_km  cost_trip
# 0             28.0         NaN       NaN        NaN
# 1             40.0         NaN       NaN        NaN
# 2             51.2         NaN       NaN        NaN
# 3             64.1         NaN       NaN        NaN
# 4             82.6         NaN       NaN        NaN
# ..             ...         ...       ...        ...
# 383          513.4         NaN       NaN        NaN
# 384          529.5         NaN       NaN        NaN
# 385          545.5         NaN       NaN        NaN
# 386          560.9         NaN       NaN        NaN
# 387          575.6         NaN       NaN        NaN
#
# [388 rows x 13 columns]

# %% [markdown]
# # Graficas
#
# Veamos algunas gráficas que nos ayuden a entender la inforamción

# %%
df.distance.plot();

# %% [markdown]
# Vemos que hay 6 tramos en los que dice haber recorrido entre 100 y 200 km, mientras que el resto está, generalmente en distancia no mayores de 50km

# %% [markdown]
# Si observamos los kilémetros recorridos por jornada tendremos un diente de sierra:

# %%
fig=df.km_recorridos.plot();

# %% [markdown]
# Vemos los cambios de combustible:

# %%
df.gas_type.plot();

# %%
df.distance.median()
# Out:
# 14.6

# %%
df.distance.hist(bins=150);

# %% [markdown]
# Veamos una primera aproximación agrupando los datos por combustibles:

# %%
df.groupby('gas_type').sum()['distance'].plot.bar();

# %% [markdown]
# Se ha recorrido mucha más distancia con SP98

# %% [markdown]
# Veamos la media de consumo agrupado por combustibles:

# %%
df.groupby('gas_type').mean()['consume']
# Out:
# gas_type
# 0    4.931250
# 1    4.899123
# Name: consume, dtype: float64

# %%
df.groupby('gas_type').mean()['consume'].plot.bar();

# %%
df.groupby('gas_type').median()['consume'].plot.bar();

# %% [markdown]
# Vemos que, a lo bruto hay más consumo en litros en E10
#
# La verdad es que aparentemente ambos combustibles en valores promedio varian muy poco. Aunque parece que el consumo es mayor el consumo de E10
#
# Sabemos que:
#
# E10 cuesta 1,38€
# SP98cu  cuesta 1,46€
#
# ¿Seríamos capaces de, grosso modo, averiguar cuánto nos ha salido de meedia con uno y otro combustible?

# %%
df
# Out:
#      distance  consume  speed  temp_outside  gas_type   AC  rain  sun  snow  \
# 0        28.0      5.0     26            12         0  0.0   0.0  0.0     0
# 1        12.0      4.2     30            13         0  0.0   0.0  0.0     0
# 2        11.2      5.5     38            15         0  0.0   0.0  0.0     0
# 3        12.9      3.9     36            14         0  0.0   0.0  0.0     0
# 4        18.5      4.5     46            15         0  0.0   0.0  0.0     0
# ..        ...      ...    ...           ...       ...  ...   ...  ...   ...
# 383      16.0      3.7     39            18         1  0.0   0.0  0.0     0
# 384      16.1      4.3     38            31         1  1.0   0.0  0.0     0
# 385      16.0      3.8     45            19         1  0.0   0.0  0.0     0
# 386      15.4      4.6     42            31         1  1.0   0.0  0.0     0
# 387      14.7      5.0     25            30         1  1.0   0.0  0.0     0
#
#      km_recorridos  price_fuel  euros_km  cost_trip
# 0             28.0         NaN       NaN        NaN
# 1             40.0         NaN       NaN        NaN
# 2             51.2         NaN       NaN        NaN
# 3             64.1         NaN       NaN        NaN
# 4             82.6         NaN       NaN        NaN
# ..             ...         ...       ...        ...
# 383          513.4         NaN       NaN        NaN
# 384          529.5         NaN       NaN        NaN
# 385          545.5         NaN       NaN        NaN
# 386          560.9         NaN       NaN        NaN
# 387          575.6         NaN       NaN        NaN
#
# [388 rows x 13 columns]

# %% [markdown]
# Podemos la información de €/kilometro de cada trayecto yu el coste de cada trayecto:

# %% [markdown]
# La velocidad media es de:

# %%
round(df.speed.mean(),0)
# Out:
# 42.0

# %% [markdown]
# Con una desviación estándar de

# %%
round(df.speed.std(),1)
# Out:
# 13.6

# %%
sns.scatterplot(data=df, x='speed', y='consume', hue='gas_type');

# %% [markdown]
# El consumo, con aire acondicionado sube:

# %%
df.groupby('AC').mean()['consume']
# Out:
# AC
# 0.0    4.883520
# 1.0    5.256667
# Name: consume, dtype: float64

# %%
sns.scatterplot(data=df, x='AC', y='consume', hue='gas_type');

# %%
sns.scatterplot(data=df, x='consume', y='temp_outside', hue='AC');

# %%
df.groupby('gas_type').mean()['euros_km']
# Out:
# gas_type
# 0   NaN
# 1   NaN
# Name: euros_km, dtype: float64

# %% [markdown]
# Vemos cómo el consumo de mayores distancias se mantiene:

# %%
sns.scatterplot(data=df, x='distance', y='euros_km', hue='gas_type');

# %%
df_cortas=df[df.distance<=50].copy()
df_largas=df[df.distance>50].copy()

# %%
sns.scatterplot(data=df_cortas, x='distance', y='euros_km', hue='gas_type');

# %%
sns.scatterplot(data=df_largas, x='distance', y='euros_km', hue='gas_type');

# %%
sns.scatterplot(data=df_cortas, x='speed', y='euros_km', hue='gas_type');

# %%
sns.scatterplot(data=df_cortas, x='distance', y='euros_km', hue='AC');

# %%
sns.scatterplot(data=df_largas, x='euros_km', y='distance', hue='AC');

# %%
df.snow.value_counts()
# Out:
# 0    384
# 1      4
# Name: snow, dtype: int64

# %%
sns.scatterplot(data=df[df.AC == 1], x='speed', y='euros_km', hue='AC');

# %%
sns.scatterplot(data=df[df.AC == 0], x='dif_int_ext', y='euros_km', hue='AC');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-d3fc7351db0b> in <module>
# ----> 1 sns.scatterplot(data=df[df.AC == 0], x='dif_int_ext', y='euros_km', hue='AC');
#
# ~/.local/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.local/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     799
#     800     variables = _ScatterPlotter.get_semantics(locals())
# --> 801     p = _ScatterPlotter(
#     802         data=data, variables=variables,
#     803         x_bins=x_bins, y_bins=y_bins,
#
# ~/.local/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# ~/.local/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/.local/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~/.local/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `dif_int_ext` for parameter `x`

# %%
sns.scatterplot(data=df, x='dif_int_ext', y='euros_km');

# %%
df[['euros_km','dif_int_ext']].corr()
